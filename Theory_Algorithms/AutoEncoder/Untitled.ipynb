# %%
import math
triple=[]
for z in range(1000):
    for x in range(1,z):
        y=math.sqrt(z**(2)-x**(2))
        if y==int(y):
            triple.append((x,y,z))

# %%
triple
# Out:
# [(3, 4.0, 5),
#  (4, 3.0, 5),
#  (6, 8.0, 10),
#  (8, 6.0, 10),
#  (5, 12.0, 13),
#  (12, 5.0, 13),
#  (9, 12.0, 15),
#  (12, 9.0, 15),
#  (8, 15.0, 17),
#  (15, 8.0, 17),
#  (12, 16.0, 20),
#  (16, 12.0, 20),
#  (7, 24.0, 25),
#  (15, 20.0, 25),
#  (20, 15.0, 25),
#  (24, 7.0, 25),
#  (10, 24.0, 26),
#  (24, 10.0, 26),
#  (20, 21.0, 29),
#  (21, 20.0, 29),
#  (18, 24.0, 30),
#  (24, 18.0, 30),
#  (16, 30.0, 34),
#  (30, 16.0, 34),
#  (21, 28.0, 35),
#  (28, 21.0, 35),
#  (12, 35.0, 37),
#  (35, 12.0, 37),
#  (15, 36.0, 39),
#  (36, 15.0, 39),
#  (24, 32.0, 40),
#  (32, 24.0, 40),
#  (9, 40.0, 41),
#  (40, 9.0, 41),
#  (27, 36.0, 45),
#  (36, 27.0, 45),
#  (14, 48.0, 50),
#  (30, 40.0, 50),
#  (40, 30.0, 50),
#  (48, 14.0, 50),
#  (24, 45.0, 51),
#  (45, 24.0, 51),
#  (20, 48.0, 52),
#  (48, 20.0, 52),
#  (28, 45.0, 53),
#  (45, 28.0, 53),
#  (33, 44.0, 55),
#  (44, 33.0, 55),
#  (40, 42.0, 58),
#  (42, 40.0, 58),
#  (36, 48.0, 60),
#  (48, 36.0, 60),
#  (11, 60.0, 61),
# ...
